# %%
import config as cfg

from common import dataset
# Out:
# Using TensorFlow backend.

# %%
scans = [
    'NKI-RS-22-1',
    'NKI-RS-22-2',
    'NKI-RS-22-3',
    'NKI-RS-22-4',
    'NKI-RS-22-5',
    'NKI-RS-22-6',
    'NKI-RS-22-7',
    'NKI-RS-22-8',
    'NKI-RS-22-9',
    'NKI-RS-22-10',
    'NKI-RS-22-11',
    'NKI-RS-22-12',
    'NKI-RS-22-13',
    'NKI-RS-22-14',
    'NKI-RS-22-15',
    'NKI-RS-22-16',
    'NKI-RS-22-17',
    'NKI-RS-22-18',
    'NKI-RS-22-19',
    'NKI-RS-22-20',
    'NKI-TRT-20-1',
    'NKI-TRT-20-2',
    'NKI-TRT-20-3',
    'NKI-TRT-20-4',
    'NKI-TRT-20-5',
    'NKI-TRT-20-6',
    'NKI-TRT-20-7',
    'NKI-TRT-20-8',
    'NKI-TRT-20-9',
    'NKI-TRT-20-10',
    'NKI-TRT-20-11',
    'NKI-TRT-20-12',
    'NKI-TRT-20-13',
    'NKI-TRT-20-14',
    'NKI-TRT-20-15',
    'NKI-TRT-20-16',
    'NKI-TRT-20-17',
    'NKI-TRT-20-18',
    'NKI-TRT-20-19',
    'NKI-TRT-20-20',
    'OASIS-TRT-20-1',
    'OASIS-TRT-20-2',
    'OASIS-TRT-20-3',
    'OASIS-TRT-20-4',
    'OASIS-TRT-20-5',
    'OASIS-TRT-20-6',
    'OASIS-TRT-20-7',
    'OASIS-TRT-20-8',
    'OASIS-TRT-20-9',
    'OASIS-TRT-20-10',
    'OASIS-TRT-20-11',
    'OASIS-TRT-20-12',
    'OASIS-TRT-20-13',
    'OASIS-TRT-20-14',
    'OASIS-TRT-20-15',
    'OASIS-TRT-20-16',
    'OASIS-TRT-20-17',
    'OASIS-TRT-20-18',
    'OASIS-TRT-20-19',
    'OASIS-TRT-20-20'
]

# %%
my_dataset = dataset.MyDataset(
    collection_name = cfg.dataset['collection_name'],
    input_label_niftii = cfg.dataset['input_label_niftii'],
    input_image_niftii = cfg.dataset['input_image_niftii'],
    labels = cfg.dataset['labels'],
    width=cfg.dataset['width'],
    height=cfg.dataset['height'],
    depth=cfg.dataset['depth'],
    scans=scans
)

# %%
my_dataset.create_dataset_3d()
# Out:
# Loading from ./input/niftii/NKI-RS-22-1/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-1.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-1/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-1.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-2/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-2.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-2/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-2.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-3/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-3.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-3/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-3.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-4/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-4.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-4/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-4.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-5/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-5.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-5/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-5.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-6/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-6.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-6/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-6.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-7/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-7.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-7/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-7.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-8/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-8.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-8/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-8.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-9/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-9.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-9/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-9.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-10/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-10.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-10/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-10.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-11/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-11.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-11/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-11.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-12/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-12.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-12/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-12.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-13/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-13.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-13/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-13.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-14/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-14.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-14/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-14.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-15/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-15.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-15/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-15.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-16/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-16.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-16/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-16.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-17/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-17.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-17/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-17.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-18/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-18.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-18/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-18.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-19/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-19.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-19/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-19.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-20/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-RS-22-20.npy
# Done.
# Loading from ./input/niftii/NKI-RS-22-20/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-RS-22-20.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-1/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-1.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-1/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-1.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-2/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-2.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-2/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-2.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-3/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-3.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-3/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-3.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-4/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-4.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-4/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-4.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-5/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-5.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-5/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-5.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-6/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-6.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-6/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-6.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-7/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-7.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-7/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-7.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-8/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-8.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-8/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-8.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-9/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-9.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-9/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-9.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-10/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-10.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-10/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-10.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-11/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-11.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-11/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-11.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-12/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-12.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-12/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-12.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-13/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-13.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-13/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-13.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-14/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-14.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-14/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-14.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-15/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-15.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-15/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-15.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-16/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-16.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-16/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-16.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-17/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-17.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-17/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-17.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-18/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-18.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-18/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-18.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-19/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-19.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-19/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-19.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-20/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/NKI-TRT-20-20.npy
# Done.
# Loading from ./input/niftii/NKI-TRT-20-20/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/NKI-TRT-20-20.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-1/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-1.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-1/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-1.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-2/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-2.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-2/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-2.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-3/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-3.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-3/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-3.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-4/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-4.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-4/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-4.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-5/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-5.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-5/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-5.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-6/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-6.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-6/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-6.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-7/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-7.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-7/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-7.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-8/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-8.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-8/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-8.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-9/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-9.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-9/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-9.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-10/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-10.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-10/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-10.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-11/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-11.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-11/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-11.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-12/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-12.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-12/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-12.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-13/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-13.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-13/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-13.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-14/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-14.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-14/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-14.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-15/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-15.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-15/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-15.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-16/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-16.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-16/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-16.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-17/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-17.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-17/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-17.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-18/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-18.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-18/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-18.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-19/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-19.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-19/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-19.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-20/t1weighted_2std.nii.gz...
# Saving images as ./input/datasets/mindboggle_scaled_order/images/OASIS-TRT-20-20.npy
# Done.
# Loading from ./input/niftii/OASIS-TRT-20-20/aseg-in-t1weighted_2std.nii.gz
# Saving labels as ./input/datasets/mindboggle_scaled_order/labels/OASIS-TRT-20-20.npy
# Done.
